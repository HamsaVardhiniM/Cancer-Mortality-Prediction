# %% [markdown]
# # Exploring the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cancer_reg.csv")
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
df.describe()
# Out:
#         avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medincome    popest2015  povertypercent  studypercap    medianage  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3047 non-null   float64
#  1   avgdeathsperyear         3047 non-null   int64
#  2   target_deathrate         3047 non-null   float64
#  3   incidencerate            3047 non-null   float64
#  4   medincome                3047 non-null   int64
#  5   popest2015               3047 non-null   int64
#  6   povertypercent           3047 non-null   float64
#  7   studypercap              3047 non-null   float64
#  8   binnedinc                3047 non-null   object
#  9   medianage                3047 non-null   float64
#  10  medianagemale            3047 non-null   float64
#  11  medianagefemale          3047 non-null   float64
#  12  geography                3047 non-null   object
#  13  avghouseholdsize         3047 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'binnedinc',
#        'medianage', 'medianagemale', 'medianagefemale', 'geography',
#        'avghouseholdsize', 'percentmarried', 'pctnohs18_24', 'pcths18_24',
#        'pctsomecol18_24', 'pctbachdeg18_24', 'pcths25_over',
#        'pctbachdeg25_over', 'pctemployed16_over', 'pctunemployed16_over',
#        'pctprivatecoverage', 'pctprivatecoveragealone', 'pctempprivcoverage',
#        'pctpubliccoverage', 'pctpubliccoveragealone', 'pctwhite', 'pctblack',
#        'pctasian', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate'],
#       dtype='object')

# %% [markdown]
# # Checking for null values

# %%
null_vals=df.isnull().sum()
print(null_vals[null_vals>0])
# Out:
# pctsomecol18_24            2285
# pctemployed16_over          152
# pctprivatecoveragealone     609
# dtype: int64

# %% [markdown]
# ## Handling null values

# %% [markdown]
# ### for each col with null values, if more than 50 percent of the entire data in the col are null avlues, then the col is dropped, else the null values are filled with the mean of the col

# %%
def handle_null_values(df):
    
    total_rows = len(df)
    for column in df.columns:
        null_count = df[column].isnull().sum()
        if null_count > 0:
            if null_count > (0.5 * total_rows):
                df.drop(columns=[column], inplace=True)
               
            else:
                mean_value = df[column].mean()
                df[column].fillna(mean_value, inplace=True)
    return df

# %%
df = handle_null_values(df)

# %%
null_vals=df.isnull().sum()
print(null_vals[null_vals>0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Null values are either removed or filled with mean

# %% [markdown]
# ## Checking for constant columns

# %% [markdown]
# ### Constant column(a col in which all the values are same), it means that the col does not paly a role in the prediction of the target variable, in other words, it does not affect the target variable, so it can be removed

# %%
def drop_constant_columns(df):
    for column in df.columns:
        if df[column].nunique() == 1:
            df.drop(columns=[column], inplace=True)
    return df

# %%
df = drop_constant_columns(df)

# %%
df.shape
# Out:
# (3047, 33)

# %% [markdown]
# ## Checking for numerical  cols with very few unique values

# %%
def few_uniq_vals_columns(df):
    for column in df.columns:
        if df[column].nunique() <3 :
            df.drop(columns=[column], inplace=True)
    return df

# %%
df=few_uniq_vals_columns(df)

# %%
df.shape
# Out:
# (3047, 33)

# %% [markdown]
# ## Checking for duplicated rows and removing them

# %%
def drop_duplicate_rows(df):
    df=df.drop_duplicates()
    return df

# %%
df= drop_duplicate_rows(df)

# %%
df.shape
# Out:
# (3047, 33)

# %% [markdown]
# ## Analysing each column

# %% [markdown]
# ### Target deathrate

# %%
plt.hist(df['target_deathrate'],color='blue',edgecolor='black')
plt.xlabel("Target deathrate")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# ### It can be seen that there are outliers in the data

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure(data=[go.Box(y=df['target_deathrate'], boxpoints='outliers', jitter=0.2, pointpos=-1.8)])
fig.update_layout(
    title='Boxplot of Death Rate',
    yaxis_title='Death Rate',
    width=700,
    height=500)
fig.show()

# %% [markdown]
# ### By visual inspection we can conclude that there are outliers in data

# %% [markdown]
# ## Splitting the range column into two cols(upper range  and lower range)

# %%
df[['binnedinc_lower', 'binnedinc_higher']] = df['binnedinc'].str.extract(r'\((.*), (.*)\]').astype(float)

# Drop the original 'binnedinc' column
df.drop(columns=['binnedinc'], inplace=True)

# %%
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap  medianage  medianagemale  ...  \
# 0      260131            11.2   499.748204       39.3           36.9  ...
# 1       43269            18.6    23.111234       33.0           32.2  ...
# 2       21026            14.6    47.560164       45.0           44.0  ...
# 3       75882            17.1   342.637253       42.8           42.2  ...
# 4       10321            12.5     0.000000       48.3           47.8  ...
#
# ...

# %%
df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'medianage',
#        'medianagemale', 'medianagefemale', 'geography', 'avghouseholdsize',
#        'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctbachdeg18_24',
#        'pcths25_over', 'pctbachdeg25_over', 'pctemployed16_over',
#        'pctunemployed16_over', 'pctprivatecoverage', 'pctprivatecoveragealone',
#        'pctempprivcoverage', 'pctpubliccoverage', 'pctpubliccoveragealone',
#        'pctwhite', 'pctblack', 'pctasian', 'pctotherrace',
#        'pctmarriedhouseholds', 'birthrate', 'binnedinc_lower',
#        'binnedinc_higher'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3047 non-null   float64
#  1   avgdeathsperyear         3047 non-null   int64
#  2   target_deathrate         3047 non-null   float64
#  3   incidencerate            3047 non-null   float64
#  4   medincome                3047 non-null   int64
#  5   popest2015               3047 non-null   int64
#  6   povertypercent           3047 non-null   float64
#  7   studypercap              3047 non-null   float64
#  8   medianage                3047 non-null   float64
#  9   medianagemale            3047 non-null   float64
#  10  medianagefemale          3047 non-null   float64
#  11  geography                3047 non-null   object
#  12  avghouseholdsize         3047 non-null   float64
#  13  percentmarried           3047 non-null   float64
# ...

# %% [markdown]
# ## Handling the outliers

# %% [markdown]
# ## Finding the normally distributed cols using Shapiro- Wilk Test

# %%
from scipy.stats import shapiro

def check_normal_distribution(df):
    normally_distributed_cols = []
    for column in df.select_dtypes(include=['number']).columns:
        stat, p_value = shapiro(df[column].dropna())
        if p_value > 0.05:
            normally_distributed_cols.append(column)
    
    return normally_distributed_cols

# %%
normally_distributed_cols=check_normal_distribution(df)
print(normally_distributed_cols)
# Out:
# ['pctpubliccoverage']

# %% [markdown]
# ## Checking for outliers in normally_distributed_cols

# %%
def find_outliers(df, normally_distributed_cols):
    outliers_present = []
    
    for column in normally_distributed_cols:
        mean_value = df[column].mean()
        std_dev = df[column].std()
        
        #  upper and lower limits for outliers
        upper_limit = mean_value + 3 * std_dev
        lower_limit = mean_value - 3 * std_dev
        outliers = df[(df[column] > upper_limit) | (df[column] < lower_limit)]
        if not outliers.empty:
            outliers_present.append(column)
            num_outliers = ((df[column] > upper_limit) | (df[column] < lower_limit)).sum()
            print( " number of outliers:",num_outliers)
    
    return outliers_present

# %%
outliers_present = find_outliers(df, normally_distributed_cols)
print(outliers_present)
# Out:
#  number of outliers: 5
# ['pctpubliccoverage']

# %%
fig = go.Figure(data=[go.Box(y=df['pctpubliccoverage'], boxpoints='outliers', jitter=0.2, pointpos=-1.8)])
fig.update_layout(
    title='Boxplot of Death Rate',
    yaxis_title='Death Rate',
    width=700,
    height=500)
fig.show()

# %% [markdown]
# ## Removing the outliers (Trimming)

# %%
def remove_outliers(df, normally_distributed_cols):
    for column in normally_distributed_cols:
        mean_value = df[column].mean()
        std_dev = df[column].std()
        upper_limit = mean_value + 3 * std_dev
        lower_limit = mean_value - 3 * std_dev
        df = df[(df[column] <= upper_limit) & (df[column] >= lower_limit)]
    
    return df

# %%
df=remove_outliers(df, normally_distributed_cols)

# %%
df.shape
# Out:
# (3042, 34)

# %% [markdown]
# ## Checking for skewed columns

# %%
def find_skewed_columns(df):
    skewed_cols = []
    
    for column in df.select_dtypes(include=['number']).columns:
        skewness = df[column].skew()
        if abs(skewness) > 1:
            skewed_cols.append(column)
    
    return skewed_cols

# %%
skewed_columns=find_skewed_columns(df)
print(skewed_columns)
# Out:
# ['avganncount', 'avgdeathsperyear', 'medincome', 'popest2015', 'studypercap', 'medianage', 'avghouseholdsize', 'pctbachdeg18_24', 'pctbachdeg25_over', 'pctwhite', 'pctblack', 'pctasian', 'pctotherrace', 'birthrate', 'binnedinc_higher']

# %%
print(len(skewed_columns))
# Out:
# 15

# %% [markdown]
# ### Visualizing skewed cols

# %%
from plotly.subplots import make_subplots

def visualize_skewed_columns(df, skewed_columns):
    fig = make_subplots(rows=len(skewed_columns), cols=1, subplot_titles=skewed_columns)

    for i, column in enumerate(skewed_columns):
        fig.add_trace(go.Histogram(x=df[column], name=column, nbinsx=30), row=i+1, col=1)

    fig.update_layout(
        height=300 * len(skewed_columns), 
        title_text="Histograms of Skewed Columns",
        showlegend=False
    )
    fig.show()

# %%
visualize_skewed_columns(df, skewed_columns)

# %%
import seaborn as sns
fig, axes = plt.subplots(len(skewed_columns), 1, figsize=(8, 6 * len(skewed_columns)))
for i, column in enumerate(skewed_columns):
    sns.kdeplot(df[column], color='blue', ax=axes[i])
    axes[i].set_title(f"Density Plot of {column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import seaborn as sns
#       2 fig, axes = plt.subplots(len(skewed_columns), 1, figsize=(8, 6 * len(skewed_columns)))
#       3 for i, column in enumerate(skewed_columns):
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
def box_plot(df, col):
    fig = go.Figure(data=[go.Box(y=df[col], boxpoints='outliers', jitter=0.3, pointpos=-1.8)])
    fig.update_layout(
        title='Boxplot of ' + col,
        yaxis_title=col,
        width=500,
        height=500)
    fig.show()

for col in skewed_columns:
    box_plot(df, col)
# Out:
# <div>                            <div id="c34e079c-9252-4776-a338-176affd55cbd" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c34e079c-9252-4776-a338-176affd55cbd")) {                    Plotly.newPlot(                        "c34e079c-9252-4776-a338-176affd55cbd",                        [{"boxpoints":"outliers","jitter":0.3,"pointpos":-1.8,"y":[1397.0,173.0,102.0,427.0,57.0,428.0,250.0,146.0,88.0,4025.0,113.0,740.0,55.0,3438.0,2265.0,251.0,1390.0,32.0,305.0,1081.0,134.0,958.0,94.0,499.0,152.0,80.0,164.0,564.0,50.0,70.0,25.0,280.0,45.0,58.0,250.0,145.0,218.0,68.0,449.0,182.0,245.0,1285.0,124.0,139.0,245.0,137.0,373.0,208.0,168.0,418.0,170.0,163.0,382.0,86.0,105.0,160.0,308.0,45.0,45.0,50.0,183.0,328.0,482.0,161.0,72.0,89.0,76.0,87.0,56.0,61.0,142
# ...

# %% [markdown]
# ### Removing the outliers

# %%
def find_outlier_columns(df, skewed_cols):
    outlier_cols = []

    for col in skewed_cols:
        if col in df.columns:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_range = Q1 - 1.5 * IQR
            upper_range = Q3 + 1.5 * IQR

            if ((df[col] < lower_range) | (df[col] > upper_range)).any():
                outlier_cols.append(col)

    return outlier_cols

# %%
outlier_cols=find_outlier_columns(df, skewed_columns)
print(outlier_cols)
# Out:
# ['avganncount', 'avgdeathsperyear', 'medincome', 'popest2015', 'studypercap', 'medianage', 'avghouseholdsize', 'pctbachdeg18_24', 'pctbachdeg25_over', 'pctwhite', 'pctblack', 'pctasian', 'pctotherrace', 'birthrate', 'binnedinc_higher']

# %%
print(len(outlier_cols))
# Out:
# 15

# %% [markdown]
# ## Capping the outliers

# %%
def replace_outliers(df, skewed_cols):
    for col in skewed_cols:
        if col in df.columns:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_range = Q1 - 1.5 * IQR
            upper_range = Q3 + 1.5 * IQR

            df[col] = df[col].apply(lambda x: lower_range if x < lower_range else (upper_range if x > upper_range else x))
    
    return df

# %%
df=replace_outliers(df, outlier_cols)
df.shape
# Out:
# (3042, 34)

# %%
def box_plot(df, col):
    fig = go.Figure(data=[go.Box(y=df[col], boxpoints='outliers', jitter=0.3, pointpos=-1.8)])
    fig.update_layout(
        title='Boxplot of ' + col,
        yaxis_title=col,
        width=500,
        height=500)
    fig.show()

for col in outlier_cols :
    box_plot(df, col)

# %% [markdown]
# ### All the ouliers are taken care of.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3042 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3042 non-null   float64
#  1   avgdeathsperyear         3042 non-null   float64
#  2   target_deathrate         3042 non-null   float64
#  3   incidencerate            3042 non-null   float64
#  4   medincome                3042 non-null   float64
#  5   popest2015               3042 non-null   float64
#  6   povertypercent           3042 non-null   float64
#  7   studypercap              3042 non-null   float64
#  8   medianage                3042 non-null   float64
#  9   medianagemale            3042 non-null   float64
#  10  medianagefemale          3042 non-null   float64
#  11  geography                3042 non-null   object
#  12  avghouseholdsize         3042 non-null   float64
# ...

# %%
df.shape
# Out:
# (3042, 34)

# %%
df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'medianage',
#        'medianagemale', 'medianagefemale', 'geography', 'avghouseholdsize',
#        'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctbachdeg18_24',
#        'pcths25_over', 'pctbachdeg25_over', 'pctemployed16_over',
#        'pctunemployed16_over', 'pctprivatecoverage', 'pctprivatecoveragealone',
#        'pctempprivcoverage', 'pctpubliccoverage', 'pctpubliccoveragealone',
#        'pctwhite', 'pctblack', 'pctasian', 'pctotherrace',
#        'pctmarriedhouseholds', 'birthrate', 'binnedinc_lower',
#        'binnedinc_higher'],
#       dtype='object')

# %%
df['geography']
# Out:
# 0          Kitsap County, Washington
# 1        Kittitas County, Washington
# 2       Klickitat County, Washington
# 3           Lewis County, Washington
# 4         Lincoln County, Washington
#                     ...
# 3042        Ellsworth County, Kansas
# 3043           Finney County, Kansas
# 3044             Ford County, Kansas
# 3045         Franklin County, Kansas
# 3046            Geary County, Kansas
# Name: geography, Length: 3042, dtype: object

# %% [markdown]
# ## Splitting the geography column into two new columns, named County and State

# %%
df[['County Name', 'State']] = df['geography'].str.split(', ', expand=True)

# %%
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0     1180.375             330.5             164.9          489.8    61898.0
# 1      173.000              70.0             161.3          411.6    48127.0
# 2      102.000              50.0             174.7          349.7    49348.0
# 3      427.000             202.0             194.8          430.4    44243.0
# 4       57.000              26.0             144.4          350.1    49955.0
#
#    popest2015  povertypercent  studypercap  medianage  medianagemale  ...  \
# 0  154005.375            11.2   208.282769       39.3           36.9  ...
# 1   43269.000            18.6    23.111234       33.0           32.2  ...
# 2   21026.000            14.6    47.560164       45.0           44.0  ...
# 3   75882.000            17.1   208.282769       42.8           42.2  ...
# 4   10321.000            12.5     0.000000       48.3           47.8  ...
#
# ...

# %%
df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'medianage',
#        'medianagemale', 'medianagefemale', 'geography', 'avghouseholdsize',
#        'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctbachdeg18_24',
#        'pcths25_over', 'pctbachdeg25_over', 'pctemployed16_over',
#        'pctunemployed16_over', 'pctprivatecoverage', 'pctprivatecoveragealone',
#        'pctempprivcoverage', 'pctpubliccoverage', 'pctpubliccoveragealone',
#        'pctwhite', 'pctblack', 'pctasian', 'pctotherrace',
#        'pctmarriedhouseholds', 'birthrate', 'binnedinc_lower',
#        'binnedinc_higher', 'County Name', 'State'],
#       dtype='object')

# %%
df1=df

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['County Name'] = label_encoder.fit_transform(df['County Name'])
df['State'] = label_encoder.fit_transform(df['State'])

# %%
df = handle_null_values(df)

# %%
df.shape
# Out:
# (3042, 36)

# %%
null_vals=df.isnull().sum()
print(null_vals[null_vals>0])
# Out:
# Series([], dtype: int64)

# %%
df.isnull().sum()
# Out:
# avganncount                0
# avgdeathsperyear           0
# target_deathrate           0
# incidencerate              0
# medincome                  0
# popest2015                 0
# povertypercent             0
# studypercap                0
# medianage                  0
# medianagemale              0
# medianagefemale            0
# geography                  0
# avghouseholdsize           0
# percentmarried             0
# pctnohs18_24               0
# pcths18_24                 0
# pctbachdeg18_24            0
# pcths25_over               0
# pctbachdeg25_over          0
# pctemployed16_over         0
# pctunemployed16_over       0
# pctprivatecoverage         0
# pctprivatecoveragealone    0
# pctempprivcoverage         0
# pctpubliccoverage          0
# pctpubliccoveragealone     0
# pctwhite                   0
# pctblack                   0
# pctasian                   0
# pctotherrace               0
# pctmarriedhouseholds       0
# birthrate                  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3042 entries, 0 to 3046
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3042 non-null   float64
#  1   avgdeathsperyear         3042 non-null   float64
#  2   target_deathrate         3042 non-null   float64
#  3   incidencerate            3042 non-null   float64
#  4   medincome                3042 non-null   float64
#  5   popest2015               3042 non-null   float64
#  6   povertypercent           3042 non-null   float64
#  7   studypercap              3042 non-null   float64
#  8   medianage                3042 non-null   float64
#  9   medianagemale            3042 non-null   float64
#  10  medianagefemale          3042 non-null   float64
#  11  geography                3042 non-null   object
#  12  avghouseholdsize         3042 non-null   float64
# ...

# %%
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0     1180.375             330.5             164.9          489.8    61898.0
# 1      173.000              70.0             161.3          411.6    48127.0
# 2      102.000              50.0             174.7          349.7    49348.0
# 3      427.000             202.0             194.8          430.4    44243.0
# 4       57.000              26.0             144.4          350.1    49955.0
#
#    popest2015  povertypercent  studypercap  medianage  medianagemale  ...  \
# 0  154005.375            11.2   208.282769       39.3           36.9  ...
# 1   43269.000            18.6    23.111234       33.0           32.2  ...
# 2   21026.000            14.6    47.560164       45.0           44.0  ...
# 3   75882.000            17.1   208.282769       42.8           42.2  ...
# 4   10321.000            12.5     0.000000       48.3           47.8  ...
#
# ...

# %%
print(df.dtypes)
# Out:
# avganncount                float64
# avgdeathsperyear           float64
# target_deathrate           float64
# incidencerate              float64
# medincome                  float64
# popest2015                 float64
# povertypercent             float64
# studypercap                float64
# medianage                  float64
# medianagemale              float64
# medianagefemale            float64
# geography                   object
# avghouseholdsize           float64
# percentmarried             float64
# pctnohs18_24               float64
# pcths18_24                 float64
# pctbachdeg18_24            float64
# pcths25_over               float64
# pctbachdeg25_over          float64
# pctemployed16_over         float64
# pctunemployed16_over       float64
# pctprivatecoverage         float64
# pctprivatecoveragealone    float64
# pctempprivcoverage         float64
# pctpubliccoverage          float64
# pctpubliccoveragealone     float64
# pctwhite                   float64
# ...

# %%
df = df.drop('geography', axis=1)

# %%
df.shape
# Out:
# (3042, 35)

# %% [markdown]
# ### Converting the cleaned(No null vals, no outliers, all categorical cols are encoded ) to a csv

# %%
df.to_csv("Cancer_Mortality_Cleaned_data")
